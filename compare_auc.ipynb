# %%
# %run logistic_regression.py
# %run random_forest.py
# Out:
# ========== Running Logistic Model on: Patient ==========
#
#
# --- Patient - Logistic Regression ---
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.45      0.51      0.48        39
#            1       0.57      0.51      0.54        49
#
#     accuracy                           0.51        88
#    macro avg       0.51      0.51      0.51        88
# weighted avg       0.52      0.51      0.51        88
#
#
# Confusion Matrix:
# ROC AUC: 0.5877
# Top Features for Patient:
#       Feature  Importance
# 4    CO_fick        0.69
# 6       PCWa        0.52
# 8        PAs        0.50
# 10       RVs        0.44
# 5        PCW        0.43
# 44     LVSWI        0.42
# 3      CO_td        0.36
# 38  LVIDd_cm        0.36
# 25     LVIDd        0.36
# 14       RAv        0.36
# /Users/pallakdhabalia/Documents/LVAD Project/logistic_regression.py:363: FutureWarning:
#
# ...

# %%
import matplotlib.pyplot as plt

# Run both models on the Combined dataset
log_label, log_fpr, log_tpr, log_auc = run_logistic_pipeline("CombinedDataWithRV.csv", "Combined")
rf_label, rf_fpr, rf_tpr, rf_auc = run_rf_pipeline("CombinedDataWithRV.csv", "Combined")

# Plot both AUC curves
plt.figure(figsize=(8, 6))
plt.plot(log_fpr, log_tpr, label=f"Logistic Regression (AUC = {log_auc:.2f})")
plt.plot(rf_fpr, rf_tpr, label=f"Random Forest (AUC = {rf_auc:.2f})")
plt.plot([0, 1], [0, 1], 'k--', alpha=0.5)
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Best AUC Curve: Logistic vs Random Forest (Combined Data)")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# ========== Running Logistic Model on: Combined ==========
#
#
# --- Combined - Logistic Regression ---
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.47      0.50      0.49        36
#            1       0.65      0.62      0.63        53
#
#     accuracy                           0.57        89
#    macro avg       0.56      0.56      0.56        89
# weighted avg       0.58      0.57      0.57        89
#
#
# Confusion Matrix:
# ROC AUC: 0.5776
# Top Features for Combined:
#         Feature  Importance
# 76      PADP_S        1.20
# 113    RVSWI_S        0.89
# 26       LVIDs        0.87
# 110     RVMD_S        0.80
# 78   PCWPmax_S        0.78
# 46       Vw_LV        0.78
# 4      CO_fick        0.75
# 43    k_act_RV        0.74
# 90     HedSW_S        0.70
# 69       DBP_S        0.69
# /Users/pallakdhabalia/Documents/LVAD Project/logistic_regression.py:363: FutureWarning:
#
# ...
